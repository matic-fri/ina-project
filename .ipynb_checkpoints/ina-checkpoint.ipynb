# %%
import pandas as pd
import numpy as np
import os
import networkx as nx
import util

# %%
import util

# DON'T FORGET:
# pip install selenium
# pip install webdriver_manager

driver = util.get_export_files('D:/Prenosi/') # enter default downloads folder

# %%
data = util.read_txt()

# %%
filtered = util.filter_countries(data, 6, 60)
print(len(filtered))

df = util.generate_dataframe_from(data, filtered, 0)
# Out:
# 190

# %%
df
# Out:
#                                    Afghanistan  Albania   Algeria   Andorra  \
# Afghanistan                                0.0      0.0       0.0       0.0
# Albania                                    0.0      0.0       0.0       0.0
# Algeria                                    0.0      0.0       0.0       0.0
# Andorra                                    0.0      0.0       0.0       0.0
# Angola                                     0.0      0.0    2000.0  155000.0
# ...                                        ...      ...       ...       ...
# Venezuela, Bolivarian Republic of          0.0      0.0       0.0       0.0
# Viet Nam                                   0.0      0.0       0.0       0.0
# Yemen                                      0.0      0.0       0.0       0.0
# Zambia                                     0.0      0.0  497000.0       0.0
# Zimbabwe                                   0.0      0.0       0.0       0.0
#
# ...

# %%
gdp_data = pd.read_csv('data/country_data.csv')

# %%
G = util.build_graph(df, gdp_data)

# %%
len(G.edges())
# Out:
# 21609
