# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("EVAD_February2015.csv")

# %%
df[df["iso3"]=="svn"]
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 1431   svn  1997     primaryagr      227.3130       2.0290    2.4523
# 1432   svn  1997      otherprim        0.8135      41.0078    1.2136
# 1433   svn  1997         energy       11.6617       1.7331  208.6320
# 1434   svn  1997      procfoods       16.4820       0.4619    0.6922
# 1435   svn  1997     bevtobacco        1.8308       0.1069    0.1695
# ...    ...   ...            ...           ...          ...       ...
# 12739  svn  2011        finance        6.5200       2.9600    3.6500
# 12740  svn  2011      insurance        0.2400       0.2400    0.5500
# 12741  svn  2011         obsict       22.6700      19.8400   27.2800
# 12742  svn  2011      oconsumer        1.4800       3.4400    1.7200
# 12743  svn  2011      oservices       11.9700      27.8100   10.2200
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
rows = []
with open('algeria.txt') as f:
    line = f.readline()
    while line:
        if line[0] == '"':
            rows.append(line.split("\t")[:-1])
        line = f.readline()

rows
# Out:
# [['"Total"',
#   '37322036',
#   '2860377',
#   '100',
#   '-5',
#   '70',
#   '',
#   '100',
#   '3',
#   '',
#   '',
#   ''],
#  ['"Italy"',
#   '6602706',
#   '4515759',
#   '17.7',
#   '-3',
#   '84',
#   '11',
#   '2.5',
#   '2',
#   '2891',
#   '0.06',
#   ''],
#  ['"Spain"',
#   '5639436',
#   '3406474',
#   '15.1',
#   '-5',
#   '97',
#   '15',
#   '1.9',
#   '3',
#   '3890',
#   '0.05',
#   ''],
#  ['"France"',
#   '5103320',
#   '716676',
#   '13.7',
#   '1',
#   '67',
#   '6',
#   '3.2',
#   '1',
#   '3195',
#   '0.06',
#   ''],
#  ['"United States of America"',
#   '1907299',
#   '1123674',
#   '5.1',
#   '-31',
#   '279',
#   '1',
#   '13.4',
#   '3',
#   '7938',
#   '0.08',
#   ''],
#  ['"Korea, Republic of"',
#   '1902850',
#   '1705597',
#   '5.1',
#   '13',
#   '110',
#   '9',
#   '2.8',
#   '4',
#   '5699',
#   '0.09',
#   ''],
#  ['"Netherlands"',
#   '1693704',
#   '1123650',
#   '4.5',
#   '8',
#   '130',
#   '8',
#   '2.8',
#   '5',
#   '3706',
#   '0.07',
# ...

# %%
# Out:
# [1, 2]
